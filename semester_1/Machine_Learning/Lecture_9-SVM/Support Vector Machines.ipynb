# %% [markdown]
# # SVM with different Kernels

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets

# %% [markdown]
# # Iris dataset. Wwe only take the first two features.

# %%
iris = datasets.load_iris()
X = iris.data[:, :2] 
y = iris.target

# %% [markdown]
# # we create an instance of SVM and fit out data
# We do not scale our data since we want to plot the support vectors

# %%
#
kernel='rbf'
#Penalty parameter C of the error term. 
#It also controls the trade off between smooth decision boundary and classifying the training points correctly.
C=10
# Higher the value of gamma, will try to exact fit the as per training data set i.e. generalization error 
# and cause over-fitting problem.
gamma='auto'
svc = svm.SVC(kernel=kernel, C=C,gamma='auto').fit(X, y)

# %% [markdown]
# # Create a mesh to plot in

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
h = (x_max / x_min)/100
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
 np.arange(y_min, y_max, h))
plt.subplot(1, 1, 1)
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z,cmap=plt.cm.RdYlBu, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolor='black',cmap=plt.cm.RdYlBu)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(xx.min(), xx.max())
plt.title('SVC with ' + kernel + ' kernel')
plt.show()
